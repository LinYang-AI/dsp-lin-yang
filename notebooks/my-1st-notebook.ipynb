# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cm import ScalarMappable

# %%
dataset = np.random.randint(0, 100, size=(10,3))

# %%
print(dataset)
# Out:
# [[59 53 64]
#  [84 48 47]
#  [88 79 92]
#  [38 25 51]
#  [73 56 29]
#  [35 61 24]
#  [40 88 26]
#  [27 55 67]
#  [57 84  8]
#  [68 36 16]]

# %%
fig, ax = plt.subplots()
ax.scatter(dataset[:,0], dataset[:,1], dataset[:,2], cmap='viridis')
cbar = plt.colorbar(ScalarMappable(cmap='viridis'))
cbar.set_label('Column 3')
ax.set_xlabel('Column 1')
ax.set_ylabel('Column 2')
plt.show()
# Out:
# /var/folders/pg/t33xxggd1cndkk5fsb62rs_40000gn/T/ipykernel_34303/1797267730.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(dataset[:,0], dataset[:,1], dataset[:,2], cmap='viridis')
# /var/folders/pg/t33xxggd1cndkk5fsb62rs_40000gn/T/ipykernel_34303/1797267730.py:3: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(ScalarMappable(cmap='viridis'))
